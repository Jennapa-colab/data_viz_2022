# %% [markdown]
# <a href="https://colab.research.google.com/github/Jennapa-colab/data_viz_2022/blob/main/Final_DataViz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Final Exam: งานกลุ่ม Final ที่อาจารย์สุ่มให้
# ให้นักศึกษาสร้าง Dashboard แสดงรายงานเกี่ยวกับข้อมูลการตรวจโรค(ov) จาก ไฟล์ alldb.csv และ hospital_list.xlsx
#
# ( ดาวน์โหลดจาก https://drive.google.com/.../1D... )
#
# โดยข้อมูลหลักจะอยู่ใน ตาราง alldb.csv (ข้อมูลที่สมบูรณ์ที่สามารถนำมาใช้งานได้ต้องมีค่าใน column ต่อไปนี้ดังนี้
#
# * user เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น)
# * RowKey เป็น String
# * date เป็น YYYY-MM-DD
# * phone เป็น String
# * site เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น)
# * time เป็น hh-mm-ss
# * urine มีค่า String
# * ov เป็นตัวเลข มีค่าตั้งแต่ 0-4 (0 คือไม่พบโรค 1-4 คือพบโรคที่ระดับความรุนแรงต่างๆ)
# * PartitionKey เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น))
#
# ไฟล์ alldb.csv และ hospital_list.xlsx สามารถถูกเชื่อมโยงกันโดย site ในไฟล์ alldb.csv คือ hcode ในไฟล์ hospital_list.xlsx
#
# โดยข้อมูลสำคัญที่ต้องแสดงคือ
#
# * จำนวนการตรวจในแต่ละพื้นที่ (จังหวัด-อำเภอ ในไฟล์ hospital_list.xlsx) เทียบกับ จำนวนที่พบโรค (column ov ในไฟล์ alldb.csv)
# * ช่วงเวลาที่ตรวจ (date ในไฟล์ alldb.csv)
# * อื่นๆที่นักศึกษาเห็นว่าเป็นประโยชน์ (phone (ชนิดโทรศัพท์ที่ใช้บันทึก), title (คำนำหน้าชื่อ), age (อายุ))
#
# (คิดคะแนนตามกลุ่ม final โดยไฟล์ที่ทุกคนในกลุ่มต้องมีคือไฟล์ data pre-processing และ link ไปที่ Dashboard ที่สร้่างโดยเปิดให้สามารถเข้าไปดูและใช้งานได้)
#
# ส่งไม่เกิน 23.59 วันจันทร์ที่ 11 เมษายน 2565

# %% [markdown]
# # เรียกใช้ฟังฟ์ชั่น

# %%
import pandas as pd #เพื่อใช้ทำงานกับข้อมูลที่เป็นรูปแบบตาราง
import os           #เพื่อจัดการกับไฟล์ และ ตัว path ที่เราจะนำเข้า

# %%
from google.colab import drive # เชื่อมบัญชีกับ google drive
drive.mount('/content/drive') # เช็คว่าเชื่อมติดหรือไม่
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/dataviz_2021_data'

# %% [markdown]
# # Data 1 ข้อมูลหลัก

# %%
data1 = pd.read_csv(os.path.join(path,'alldb.csv'))
data1
# Out:
#        Unnamed: 0           user                                    RowKey  \
# 0               0           test                                       NaN
# 1               1          04857      136FD222-FD9F-4E54-AE1F-7282A276B085
# 2               2            NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png
# 3               3  3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE
# 4               4  3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21
# ...           ...            ...                                       ...
# 40030       40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C
# 40031       40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1
# 40032       40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9
# 40033       40033            NaN                            bbuogxulur.png
# 40034       40034            NaN                            zttpqogiso.png
#
#       care        date   ov             phone   site      time  \
# 0      NaN         NaN  NaN               NaN    NaN       NaN
# 1      NaN  2022-02-24  NaN        iPhone10,4  05310  10:50:32
# 2      NaN         NaN  NaN               NaN    NaN       NaN
# 3      NaN  2022-02-23    0        iPhone13,4  05087  09:59:47
# 4      NaN  2022-02-23  NaN        iPhone13,4  05087  09:44:06
# ...    ...         ...  ...               ...    ...       ...
# 40030  NaN         NaN  NaN        iPhone13,4  01234       NaN
# 40031  NaN         NaN    2        iPhone10,5  01234       NaN
# 40032  NaN         NaN    1        iPhone13,4  01234       NaN
# 40033  NaN         NaN  NaN  Samsung SM-A115F  01234       NaN
# 40034  NaN         NaN    1  Samsung SM-A115F  01234       NaN
#
#                  urine  pid            PartitionKey                  title  \
# 0                  NaN  NaN                     NaN  data is not completed
# 1                  NaN  NaN                     NaN  data is not completed
# 2                  NaN  NaN                     NaN  data is not completed
# 3      ปกติ (เหลืองใส)  NaN                     NaN  data is not completed
# 4      ปกติ (เหลืองใส)  NaN                     NaN  data is not completed
# ...                ...  ...                     ...                    ...
# 40030              NaN    5     เกษศิรินทร์  ไชยลาภ  data is not completed
# 40031  ปกติ (เหลืองใส)    5  เถลิงเกียรติ เสริฐเลิศ  data is not completed
# 40032  ปกติ (เหลืองใส)    1                    เสรี  data is not completed
# 40033              NaN    1                    เสรี  data is not completed
# 40034  ปกติ (เหลืองใส)    1                    เสรี  data is not completed
#
#                          age
# 0      data is not completed
# 1      data is not completed
# 2      data is not completed
# 3      data is not completed
# 4      data is not completed
# ...                      ...
# 40030  data is not completed
# 40031  data is not completed
# 40032  data is not completed
# 40033  data is not completed
# 40034  data is not completed
#
# [40035 rows x 14 columns]

# %%
data1.shape
# Out:
# (40035, 14)

# %% [markdown]
# ### ตรวจสอบหาค่า NaN หรือ Missing

# %%
data1.isnull().any()  # ตรวจสอบหาค่า missing
# Out:
# Unnamed: 0      False
# user             True
# RowKey           True
# care             True
# date             True
# ov               True
# phone            True
# site             True
# time             True
# urine            True
# pid              True
# PartitionKey     True
# title            True
# age              True
# dtype: bool

# %% [markdown]
# จากการตรวจสอบค่า missing พบว่า ทุกคอมลัมน์มีค่า missing ดังนั้นเราจึงจะทำการแก้ไขค่า missing ไปทีละคอมลัมน์

# %% [markdown]
# # Data Preprocessing

# %%
data = data1[['user','RowKey','date','ov','phone','site','time','urine','PartitionKey','title','age']]
data
# Out:
#                 user                                    RowKey        date  \
# 0               test                                       NaN         NaN
# 1              04857      136FD222-FD9F-4E54-AE1F-7282A276B085  2022-02-24
# 2                NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png         NaN
# 3      3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE  2022-02-23
# 4      3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21  2022-02-23
# ...              ...                                       ...         ...
# 40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C         NaN
# 40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1         NaN
# 40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9         NaN
# 40033            NaN                            bbuogxulur.png         NaN
# 40034            NaN                            zttpqogiso.png         NaN
#
#         ov             phone   site      time            urine  \
# 0      NaN               NaN    NaN       NaN              NaN
# 1      NaN        iPhone10,4  05310  10:50:32              NaN
# 2      NaN               NaN    NaN       NaN              NaN
# 3        0        iPhone13,4  05087  09:59:47  ปกติ (เหลืองใส)
# 4      NaN        iPhone13,4  05087  09:44:06  ปกติ (เหลืองใส)
# ...    ...               ...    ...       ...              ...
# 40030  NaN        iPhone13,4  01234       NaN              NaN
# 40031    2        iPhone10,5  01234       NaN  ปกติ (เหลืองใส)
# 40032    1        iPhone13,4  01234       NaN  ปกติ (เหลืองใส)
# 40033  NaN  Samsung SM-A115F  01234       NaN              NaN
# 40034    1  Samsung SM-A115F  01234       NaN  ปกติ (เหลืองใส)
#
#                  PartitionKey                  title                    age
# 0                         NaN  data is not completed  data is not completed
# 1                         NaN  data is not completed  data is not completed
# 2                         NaN  data is not completed  data is not completed
# 3                         NaN  data is not completed  data is not completed
# 4                         NaN  data is not completed  data is not completed
# ...                       ...                    ...                    ...
# 40030     เกษศิรินทร์  ไชยลาภ  data is not completed  data is not completed
# 40031  เถลิงเกียรติ เสริฐเลิศ  data is not completed  data is not completed
# 40032                    เสรี  data is not completed  data is not completed
# 40033                    เสรี  data is not completed  data is not completed
# 40034                    เสรี  data is not completed  data is not completed
#
# [40035 rows x 11 columns]

# %%
data_drop = data.dropna()
data_drop
# Out:
#          user                                RowKey        date ov  \
# 186    45-161  D2CABB8C-533B-450A-AFA6-B693749CC1C6  2022-02-23  0
# 187    45-161  57A5F06C-C840-49EA-9514-A30D3C897CC8  2022-02-23  0
# 188     27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1  2022-02-25  0
# 191     12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30  4
# 192     91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30  4
# ...       ...                                   ...         ... ..
# 40013   ttest                        crqcufokmn.png  2022-02-21  2
# 40014   ttest                        gzxgflnowr.png  2022-02-21  2
# 40016     xxx                        jytlopevha.png  2022-02-17  3
# 40022     yyy                        ivccsksowb.png  2022-02-17  2
# 40023     zzz                        psudrnccsh.png  2022-02-17  2
#
#                   phone   site      time            urine PartitionKey  \
# 186          iPhone11,8  04312  09:45:28  ปกติ (เหลืองใส)       0-1528
# 187          iPhone11,8  04312  10:06:45  ปกติ (เหลืองใส)       0-1544
# 188          iPhone13,1  04999  14:22:22  ปกติ (เหลืองใส)         0000
# 191          iPhone12,3  06307  14:46:08  ปกติ (เหลืองใส)        00001
# 192          iPhone14,3  05328  15:27:45  ปกติ (เหลืองใส)        00001
# ...                 ...    ...       ...              ...          ...
# 40013  Samsung SM-G998B   test  14:23:45             ขุ่น         x001
# 40014  Samsung SM-G998B   test  14:23:43             ขุ่น         x001
# 40016  Samsung SM-N950F    xxx  00:01:06  ปกติ (เหลืองใส)          xxx
# 40022  Samsung SM-N950F    yyy  08:41:05   มีเม็ดเลือดแดง          yyy
# 40023  Samsung SM-N950F    zzz  08:41:04          มีตะกอน          zzz
#
#                        title                    age
# 186    data is not completed  data is not completed
# 187    data is not completed  data is not completed
# 188    data is not completed  data is not completed
# 191                   นางสาว                     47
# 192                      นาง                     41
# ...                      ...                    ...
# 40013  data is not completed  data is not completed
# 40014  data is not completed  data is not completed
# 40016  data is not completed  data is not completed
# 40022  data is not completed  data is not completed
# 40023  data is not completed  data is not completed
#
# [38135 rows x 11 columns]

# %% [markdown]
# ### แก้ไข user, site, PartitionKey เป็นตัวเลข 5 หลัก

# %%
data_drop = data_drop[(data_drop['user'].astype(str).str.isdigit()) & (data_drop['user'].str.len() == 5)]      # เลือกมาเฉพาะ คอลัมน์ user ที่เป็นตัวเลข & มีตัวเลข เท่ากับ 5 ตัว
print(data_drop.shape)                                                                             # .str.isdigit ใช้ตรวจสอบว่าอักขระทั้งหมดเป็นตัวเลขหรือไม่
data_drop
# Out:
# (37465, 11)
#         user                                RowKey        date ov  \
# 188    27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1  2022-02-25  0
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30  4
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30  4
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  2022-03-30  3
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  2022-03-29  3
# ...      ...                                   ...         ... ..
# 39722  76331                        bbrbiwclgv.png  2022-02-23  0
# 39782  76331                        lzzsckyyqs.png  2022-02-23  0
# 39791  76331                        pvpiawlexb.png  2022-02-23  1
# 39794  68317                        rtutxrlbam.png  2022-02-23  2
# 39795  68317                        dmuragqwza.png  2022-02-23  2
#
#                   phone   site      time            urine PartitionKey  \
# 188          iPhone13,1  04999  14:22:22  ปกติ (เหลืองใส)         0000
# 191          iPhone12,3  06307  14:46:08  ปกติ (เหลืองใส)        00001
# 192          iPhone14,3  05328  15:27:45  ปกติ (เหลืองใส)        00001
# 193          iPhone13,4  06302  10:16:46  ปกติ (เหลืองใส)        00001
# 194           iPhone9,4  05059  12:26:38  ปกติ (เหลืองใส)        00001
# ...                 ...    ...       ...              ...          ...
# 39722  Samsung SM-G965U  05258  14:05:25  ปกติ (เหลืองใส)           61
# 39782  Samsung SM-G965U  05258  14:42:45  ปกติ (เหลืองใส)           89
# 39791  Samsung SM-G965U  05258  15:32:53  ปกติ (เหลืองใส)           92
# 39794  Samsung SM-A115F  28017  14:31:01  ปกติ (เหลืองใส)          976
# 39795  Samsung SM-A115F  28017  14:30:21  ปกติ (เหลืองใส)          983
#
#                        title                    age
# 188    data is not completed  data is not completed
# 191                   นางสาว                     47
# 192                      นาง                     41
# 193                      นาง                     55
# 194                      นาย                     66
# ...                      ...                    ...
# 39722  data is not completed  data is not completed
# 39782  data is not completed  data is not completed
# 39791  data is not completed  data is not completed
# 39794  data is not completed  data is not completed
# 39795  data is not completed  data is not completed
#
# [37465 rows x 11 columns]

# %%
set(data_drop['user'])
# Out:
# {'62616',
#  '11215',
#  '32082',
#  '86483',
#  '32891',
#  '83771',
#  '00281',
#  '41061',
#  '73445',
#  '00348',
#  '91811',
#  '59305',
#  '00065',
#  '06223',
#  '00071',
#  '00027',
#  '76339',
#  '96292',
#  '89576',
#  '71921',
#  '51301',
#  '03359',
#  '17560',
#  '23049',
#  '03949',
#  '00194',
#  '77509',
#  '97505',
#  '67400',
#  '72483',
#  '17790',
#  '14771',
#  '01403',
#  '52830',
#  '94392',
#  '05182',
#  '84494',
#  '66082',
#  '00009',
#  '21688',
#  '29094',
#  '05961',
#  '76803',
#  '25176',
#  '28731',
#  '11007',
#  '30283',
#  '39537',
#  '55911',
#  '43068',
#  '94019',
#  '20304',
#  '31582',
#  '42370',
#  '05663',
#  '10046',
#  '46970',
#  '28330',
#  '42173',
#  '18253',
#  '76088',
#  '51403',
#  '00318',
#  '99771',
#  '75487',
#  '77688',
#  '22354',
#  '84005',
#  '77572',
#  '79028',
#  '96349',
#  '02862',
#  '01651',
#  '19180',
#  '01721',
#  '05242',
#  '03263',
#  '00117',
#  '20291',
#  '00135',
#  '16022',
#  '03558',
#  '00211',
#  '00324',
#  '00026',
#  '98519',
#  '96481',
#  '28992',
#  '05228',
#  '44502',
#  '32581',
#  '01024',
#  '09072',
#  '44364',
#  '71781',
#  '00201',
#  '49791',
#  '00941',
#  '18873',
#  '90257',
#  '94406',
#  '09006',
#  '08773',
#  '61552',
#  '27732',
#  '77249',
#  '97281',
#  '89609',
#  '30481',
#  '25683',
#  '00055',
#  '18331',
#  '92962',
#  '00317',
#  '99884',
#  '36141',
#  '00328',
#  '48368',
#  '00277',
#  '30067',
#  '26043',
#  '17277',
#  '76096',
#  '18954',
#  '39959',
#  '00136',
#  '00145',
#  '91167',
#  '18733',
#  '00216',
#  '98156',
#  '18737',
#  '01636',
#  '61265',
#  '00162',
#  '83943',
#  '54734',
#  '63381',
#  '38500',
#  '00149',
#  '31062',
#  '94538',
#  '67094',
#  '31879',
#  '46291',
#  '83276',
#  '73557',
#  '78231',
#  '62061',
#  '16904',
#  '26477',
#  '38522',
#  '45736',
#  '30511',
#  '23596',
#  '56845',
#  '11891',
#  '68006',
#  '40059',
#  '96730',
#  '33251',
#  '48069',
#  '98703',
#  '00017',
#  '79493',
#  '76331',
#  '00291',
#  '52227',
#  '46897',
#  '73946',
#  '81065',
#  '99011',
#  '47844',
#  '19250',
#  '24563',
#  '22456',
#  '38614',
#  '44201',
#  '33100',
#  '89329',
#  '00053',
#  '81197',
#  '66437',
#  '33081',
#  '23958',
#  '01594',
#  '84187',
#  '43143',
#  '31229',
#  '18849',
#  '40533',
#  '18892',
#  '18025',
#  '02396',
#  '26445',
#  '46622',
#  '52481',
#  '00003',
#  '25071',
#  '00260',
#  '21432',
#  '16321',
#  '44805',
#  '02639',
#  '25837',
#  '88942',
#  '50911',
#  '00263',
#  '10653',
#  '79920',
#  '55075',
#  '27046',
#  '00023',
#  '72364',
#  '67615',
#  '67778',
#  '48768',
#  '67379',
#  '63200',
#  '53089',
#  '52922',
#  '29476',
#  '74523',
#  '20435',
#  '03308',
#  '40520',
#  '66155',
#  '77862',
#  '10534',
#  '35139',
#  '83662',
#  '53510',
#  '76014',
#  '38121',
#  '82951',
#  '29118',
#  '70187',
#  '89913',
#  '09315',
#  '28062',
#  '46285',
#  '00287',
#  '01008',
#  '00200',
#  '19265',
#  '19241',
#  '99376',
#  '49863',
#  '71813',
#  '11887',
#  '05047',
#  '89081',
#  '64520',
#  '00394',
#  '08741',
#  '60250',
#  '97913',
#  '00578',
#  '64081',
#  '00051',
#  '31133',
#  '14914',
#  '46520',
#  '06924',
#  '00226',
#  '45914',
#  '60879',
#  '00079',
#  '00021',
#  '18041',
#  '00157',
#  '15734',
#  '61419',
#  '00209',
#  '49322',
#  '77384',
#  '80463',
#  '76851',
#  '00319',
#  '25829',
#  '00030',
#  '50466',
#  '37728',
#  '46597',
#  '49424',
#  '11282',
#  '60147',
#  '09226',
#  '00160',
#  '05135',
#  '63865',
#  '62261',
#  '88135',
#  '86407',
#  '86547',
#  '74414',
#  '67093',
#  '42055',
#  '10487',
#  '58196',
#  '84392',
#  '80382',
#  '27096',
#  '67864',
#  '30431',
#  '70409',
#  '00152',
#  '63799',
#  '01762',
#  '94494',
#  '92073',
#  '00166',
#  '45846',
#  '67280',
#  '24491',
#  '37249',
#  '50172',
#  '82954',
#  '86299',
#  '87218',
#  '74394',
#  '53943',
#  '02604',
#  '55415',
#  '53011',
#  '16529',
#  '23738',
#  '60847',
#  '70054',
#  '39529',
#  '89394',
#  '31551',
#  '32914',
#  '92648',
#  '86474',
#  '22545',
#  '77782',
#  '80847',
#  '66501',
#  '71970',
#  '63767',
#  '34711',
#  '64385',
#  '32310',
#  '00015',
#  '19762',
#  '50837',
#  '73876',
#  '19559',
#  '03523',
#  '79834',
#  '46775',
#  '05082',
#  ...}

# %%
data_drop = data_drop[(data_drop['PartitionKey'].astype(str).str.isdigit()) & (data_drop['PartitionKey'].str.len() == 5)]      # เลือกมาเฉพาะ คอลัมน์ PartitionKey ที่เป็นตัวเลข & มีตัวเลข เท่ากับ 5 ตัว
print(data_drop.shape)                                                                            
data_drop
# Out:
# (37398, 11)
#         user                                RowKey        date ov       phone  \
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30  4  iPhone12,3
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30  4  iPhone14,3
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  2022-03-30  3  iPhone13,4
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  2022-03-29  3   iPhone9,4
# 195    28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402  2022-03-31  0  iPhone13,3
# ...      ...                                   ...         ... ..         ...
# 39416  26462                        ieotqfnqcq.png  2022-03-22  1   Vivo 1920
# 39417  26462                        cywpeqziic.png  2022-03-21  2   Vivo 1920
# 39418  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7  2022-03-22  2  iPhone13,4
# 39419  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC  2022-03-21  0  iPhone13,4
# 39420  26462                        vdxxgljykj.png  2022-03-21  1  Vivo V2050
#
#         site      time                             urine PartitionKey   title  \
# 191    06307  14:46:08                   ปกติ (เหลืองใส)        00001  นางสาว
# 192    05328  15:27:45                   ปกติ (เหลืองใส)        00001     นาง
# 193    06302  10:16:46                   ปกติ (เหลืองใส)        00001     นาง
# 194    05059  12:26:38                   ปกติ (เหลืองใส)        00001     นาย
# 195    06334  14:57:41                   ปกติ (เหลืองใส)        00001  นางสาว
# ...      ...       ...                               ...          ...     ...
# 39416  11069  14:03:12                   ปกติ (เหลืองใส)        11003  นางสาว
# 39417  11069  13:59:04                   ปกติ (เหลืองใส)        11005     นาย
# 39418  11069  13:41:47                   ปกติ (เหลืองใส)        11006     นาง
# 39419  11069  14:17:46                   ปกติ (เหลืองใส)        11007     นาง
# 39420  11069  10:54:49  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า        11008     นาย
#
#       age
# 191    47
# 192    41
# 193    55
# 194    66
# 195    50
# ...    ..
# 39416  33
# 39417  28
# 39418  72
# 39419  48
# 39420  36
#
# [37398 rows x 11 columns]

# %%
set(data_drop['PartitionKey'])
# Out:
# {'01544',
#  '02567',
#  '03464',
#  '03366',
#  '01053',
#  '00660',
#  '02925',
#  '01163',
#  '01425',
#  '00521',
#  '01623',
#  '01447',
#  '00281',
#  '03291',
#  '08929',
#  '00743',
#  '02421',
#  '00348',
#  '00065',
#  '00895',
#  '01201',
#  '00704',
#  '01750',
#  '03379',
#  '05139',
#  '00066',
#  '05318',
#  '02073',
#  '02321',
#  '06007',
#  '01641',
#  '04788',
#  '05092',
#  '05724',
#  '00573',
#  '00071',
#  '00027',
#  '01176',
#  '08934',
#  '02858',
#  '01103',
#  '02071',
#  '01484',
#  '00419',
#  '03065',
#  '03359',
#  '00369',
#  '00766',
#  '01684',
#  '02709',
#  '00359',
#  '01277',
#  '00569',
#  '01354',
#  '00595',
#  '01209',
#  '02116',
#  '03044',
#  '00973',
#  '03949',
#  '06020',
#  '08993',
#  '00194',
#  '01269',
#  '01692',
#  '00790',
#  '00575',
#  '03126',
#  '01346',
#  '00581',
#  '10967',
#  '00466',
#  '00567',
#  '01748',
#  '00983',
#  '01664',
#  '04654',
#  '03134',
#  '01855',
#  '01955',
#  '03255',
#  '01403',
#  '01227',
#  '03313',
#  '02196',
#  '00899',
#  '03273',
#  '04635',
#  '01222',
#  '02237',
#  '02803',
#  '02007',
#  '02743',
#  '00009',
#  '01256',
#  '05961',
#  '03310',
#  '03284',
#  '01652',
#  '09015',
#  '03215',
#  '01564',
#  '09043',
#  '00171',
#  '00411',
#  '00381',
#  '02055',
#  '05841',
#  '00831',
#  '05147',
#  '01011',
#  '01482',
#  '02053',
#  '02093',
#  '00814',
#  '01469',
#  '08947',
#  '02045',
#  '00517',
#  '00844',
#  '01433',
#  '02209',
#  '04641',
#  '00114',
#  '00680',
#  '02903',
#  '02977',
#  '01800',
#  '01465',
#  '00173',
#  '01155',
#  '01395',
#  '01157',
#  '02550',
#  '00657',
#  '01653',
#  '00655',
#  ...}

# %%
data_drop = data_drop[(data_drop['site'].astype(str).str.isdigit()) & (data_drop['site'].str.len() == 5)]      # เลือกมาเฉพาะ คอลัมน์ site ที่เป็นตัวเลข & มีตัวเลข เท่ากับ 5 ตัว
print(data_drop.shape)       
data_drop
# Out:
# (37392, 11)
#         user                                RowKey        date ov       phone  \
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30  4  iPhone12,3
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30  4  iPhone14,3
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  2022-03-30  3  iPhone13,4
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  2022-03-29  3   iPhone9,4
# 195    28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402  2022-03-31  0  iPhone13,3
# ...      ...                                   ...         ... ..         ...
# 39416  26462                        ieotqfnqcq.png  2022-03-22  1   Vivo 1920
# 39417  26462                        cywpeqziic.png  2022-03-21  2   Vivo 1920
# 39418  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7  2022-03-22  2  iPhone13,4
# 39419  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC  2022-03-21  0  iPhone13,4
# 39420  26462                        vdxxgljykj.png  2022-03-21  1  Vivo V2050
#
#         site      time                             urine PartitionKey   title  \
# 191    06307  14:46:08                   ปกติ (เหลืองใส)        00001  นางสาว
# 192    05328  15:27:45                   ปกติ (เหลืองใส)        00001     นาง
# 193    06302  10:16:46                   ปกติ (เหลืองใส)        00001     นาง
# 194    05059  12:26:38                   ปกติ (เหลืองใส)        00001     นาย
# 195    06334  14:57:41                   ปกติ (เหลืองใส)        00001  นางสาว
# ...      ...       ...                               ...          ...     ...
# 39416  11069  14:03:12                   ปกติ (เหลืองใส)        11003  นางสาว
# 39417  11069  13:59:04                   ปกติ (เหลืองใส)        11005     นาย
# 39418  11069  13:41:47                   ปกติ (เหลืองใส)        11006     นาง
# 39419  11069  14:17:46                   ปกติ (เหลืองใส)        11007     นาง
# 39420  11069  10:54:49  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า        11008     นาย
#
#       age
# 191    47
# 192    41
# 193    55
# 194    66
# 195    50
# ...    ..
# 39416  33
# 39417  28
# 39418  72
# 39419  48
# 39420  36
#
# [37392 rows x 11 columns]

# %%
set(data_drop['site'])
# Out:
# {'00027',
#  '00040',
#  '00513',
#  '00579',
#  '00580',
#  '02759',
#  '03432',
#  '03626',
#  '04275',
#  '04279',
#  '04280',
#  '04281',
#  '04302',
#  '04312',
#  '04313',
#  '04321',
#  '04322',
#  '04326',
# date            object
# ov              object
# phone           object
# site            object
# time            object
# urine           object
# PartitionKey    object
# title           object
# age             object
# dtype: object

# %% [markdown]
# ## เปลี่ยน type ข้อมูลเป็น String
#
# https://datatofish.com/string-to-integer-dataframe/?fbclid=IwAR2QM-BBrWO79pYmBAqndG8swBQVgxoQH4nJTAz8zGMS6VjlZone_MBVBxQ

# %%
import numpy as np

# %% [markdown]
# ### เปลี่ยน user, site, ov, PartitionKey, age เป็นตัวเลขเท่านั้น (int)

# %% [markdown]
# โดยการตั้งค่า  error='coerce' จะแปลงค่าที่ไม่ใช่ตัวเลขเป็น  NaN

# %%
#data_drop['user'] = pd.to_numeric(data_drop['user'], errors='coerce')
#data_drop['site'] = pd.to_numeric(data_drop['site'], errors='coerce')
#data_drop['PartitionKey'] = pd.to_numeric(data_drop['PartitionKey'], errors='coerce')

# %%
data_drop['ov'] = pd.to_numeric(data_drop['ov'], errors='coerce')
data_drop['age'] = pd.to_numeric(data_drop['age'], errors='coerce')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data_drop.dtypes
# Out:
# user             object
# RowKey           object
# date             object
# ov              float64
# phone            object
# site             object
# time             object
# urine            object
# PartitionKey     object
# title            object
# age               int64
# dtype: object

# %% [markdown]
# ตอนนี้จะสังเกตเห็น ค่า NaNโดยที่ประเภทข้อมูลเป็น float
#
# สามารถทำโดยแทนที่ค่า 'NaN' ด้วยค่า '0' โดยใช้ df.replace:

# %%
#data_drop['user'] = data_drop['user'].astype(int)
#data_drop['site'] = data_drop['site'].astype(int)
#data_drop['PartitionKey'] = data_drop['PartitionKey'].astype(int)

# %%
data_drop = data_drop.replace(np.nan, 0, regex=True)
data_drop['ov'] = data_drop['ov'].astype(int)
data_drop['age'] = data_drop['age'].astype(int)

# %%
data_drop.dtypes
# Out:
# user            object
# RowKey          object
# date            object
# ov               int64
# phone           object
# site            object
# time            object
# urine           object
# PartitionKey    object
# title           object
# age              int64
# dtype: object

# %%
data_drop
# Out:
#         user                                RowKey        date  ov  \
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30   4
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30   4
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  2022-03-30   3
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  2022-03-29   3
# 195    28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402  2022-03-31   0
# ...      ...                                   ...         ...  ..
# 39416  26462                        ieotqfnqcq.png  2022-03-22   1
# 39417  26462                        cywpeqziic.png  2022-03-21   2
# 39418  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7  2022-03-22   2
# 39419  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC  2022-03-21   0
# 39420  26462                        vdxxgljykj.png  2022-03-21   1
#
#             phone   site      time                             urine  \
# 191    iPhone12,3  06307  14:46:08                   ปกติ (เหลืองใส)
# 192    iPhone14,3  05328  15:27:45                   ปกติ (เหลืองใส)
# 193    iPhone13,4  06302  10:16:46                   ปกติ (เหลืองใส)
# 194     iPhone9,4  05059  12:26:38                   ปกติ (เหลืองใส)
# 195    iPhone13,3  06334  14:57:41                   ปกติ (เหลืองใส)
# ...           ...    ...       ...                               ...
# 39416   Vivo 1920  11069  14:03:12                   ปกติ (เหลืองใส)
# 39417   Vivo 1920  11069  13:59:04                   ปกติ (เหลืองใส)
# 39418  iPhone13,4  11069  13:41:47                   ปกติ (เหลืองใส)
# 39419  iPhone13,4  11069  14:17:46                   ปกติ (เหลืองใส)
# 39420  Vivo V2050  11069  10:54:49  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า
#
#       PartitionKey   title  age
# 191          00001  นางสาว   47
# 192          00001     นาง   41
# 193          00001     นาง   55
# 194          00001     นาย   66
# 195          00001  นางสาว   50
# ...            ...     ...  ...
# 39416        11003  นางสาว   33
# 39417        11005     นาย   28
# 39418        11006     นาง   72
# 39419        11007     นาง   48
# 39420        11008     นาย   36
#
# [37392 rows x 11 columns]

# %% [markdown]
# จะเห็นว่า data เป็น YYYY-MM-DD แล้ว

# %% [markdown]
# ### เปลี่ยน time เป็น hh-mm-ss

# %%
data_drop['time'] = data_drop['time'].replace(':','-',regex=True)

# %%
data_drop
# Out:
#         user                                RowKey        date  ov  \
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30   4
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30   4
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  2022-03-30   3
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  2022-03-29   3
# 195    28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402  2022-03-31   0
# ...      ...                                   ...         ...  ..
# 39416  26462                        ieotqfnqcq.png  2022-03-22   1
# 39417  26462                        cywpeqziic.png  2022-03-21   2
# 39418  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7  2022-03-22   2
# 39419  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC  2022-03-21   0
# 39420  26462                        vdxxgljykj.png  2022-03-21   1
#
#             phone   site      time                             urine  \
# 191    iPhone12,3  06307  14-46-08                   ปกติ (เหลืองใส)
# 192    iPhone14,3  05328  15-27-45                   ปกติ (เหลืองใส)
# 193    iPhone13,4  06302  10-16-46                   ปกติ (เหลืองใส)
# 194     iPhone9,4  05059  12-26-38                   ปกติ (เหลืองใส)
# 195    iPhone13,3  06334  14-57-41                   ปกติ (เหลืองใส)
# ...           ...    ...       ...                               ...
# 39416   Vivo 1920  11069  14-03-12                   ปกติ (เหลืองใส)
# 39417   Vivo 1920  11069  13-59-04                   ปกติ (เหลืองใส)
# 39418  iPhone13,4  11069  13-41-47                   ปกติ (เหลืองใส)
# 39419  iPhone13,4  11069  14-17-46                   ปกติ (เหลืองใส)
# 39420  Vivo V2050  11069  10-54-49  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า
#
#       PartitionKey   title  age
# 191          00001  นางสาว   47
# 192          00001     นาง   41
# 193          00001     นาง   55
# 194          00001     นาย   66
# 195          00001  นางสาว   50
# ...            ...     ...  ...
# 39416        11003  นางสาว   33
# 39417        11005     นาย   28
# 39418        11006     นาง   72
# 39419        11007     นาง   48
# 39420        11008     นาย   36
#
# [37392 rows x 11 columns]

# %% [markdown]
# ### เปลี่ยน RowKey, phone, urine, title เป็น String

# %%
data_drop.astype({'RowKey':'string', 'phone':'string','urine':'string','title':'string'}).dtypes
# Out:
# user            object
# RowKey          string
# date            object
# ov               int64
# phone           string
# site            object
# time            object
# urine           string
# PartitionKey    object
# title           string
# age              int64
# dtype: object

# %%
data_drop
# Out:
#         user                                RowKey        date  ov  \
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30   4
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30   4
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  2022-03-30   3
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  2022-03-29   3
# 195    28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402  2022-03-31   0
# ...      ...                                   ...         ...  ..
# 39416  26462                        ieotqfnqcq.png  2022-03-22   1
# 39417  26462                        cywpeqziic.png  2022-03-21   2
# 39418  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7  2022-03-22   2
# 39419  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC  2022-03-21   0
# 39420  26462                        vdxxgljykj.png  2022-03-21   1
#
#             phone   site      time                             urine  \
# 191    iPhone12,3  06307  14-46-08                   ปกติ (เหลืองใส)
# 192    iPhone14,3  05328  15-27-45                   ปกติ (เหลืองใส)
# 193    iPhone13,4  06302  10-16-46                   ปกติ (เหลืองใส)
# 194     iPhone9,4  05059  12-26-38                   ปกติ (เหลืองใส)
# 195    iPhone13,3  06334  14-57-41                   ปกติ (เหลืองใส)
# ...           ...    ...       ...                               ...
# 39416   Vivo 1920  11069  14-03-12                   ปกติ (เหลืองใส)
# 39417   Vivo 1920  11069  13-59-04                   ปกติ (เหลืองใส)
# 39418  iPhone13,4  11069  13-41-47                   ปกติ (เหลืองใส)
# 39419  iPhone13,4  11069  14-17-46                   ปกติ (เหลืองใส)
# 39420  Vivo V2050  11069  10-54-49  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า
#
#       PartitionKey   title  age
# 191          00001  นางสาว   47
# 192          00001     นาง   41
# 193          00001     นาง   55
# 194          00001     นาย   66
# 195          00001  นางสาว   50
# ...            ...     ...  ...
# 39416        11003  นางสาว   33
# 39417        11005     นาย   28
# 39418        11006     นาง   72
# 39419        11007     นาง   48
# 39420        11008     นาย   36
#
# [37392 rows x 11 columns]

# %% [markdown]
# ### แก้ไขค่า titile(คำนำหน้าชื่อ)

# %%
set(data_drop['title'])
# Out:
# {'  นาง',
#  ' นาง',
#  ' นางสาว',
#  ' นาย',
#  'Mrs',
#  'ชาย',
#  'ด.ช.',
#  'ด.ญ.',
#  'ด.ต.',
#  'น',
#  'น.ส',
#  'น.ส ',
#  'น.ส.',
#  'นส',
#  'นส.',
#  'นส. ',
#  'นาง',
#  'นาง ',
#  'นาง.',
#  'นางl',
#  'นางสาว',
#  'นางสาว ',
#  'นางสาว                   ',
#  'นาน',
#  'นาบ',
#  'นาย',
#  'นาย ',
#  'นาย  ',
#  'นาว',
#  'นาวสาว',
#  'นา่ง',
#  'น่าย',
#  'พจอ.',
#  'พระ',
#  'พระครุ',
#  'พระปลัด',
#  'พลฯ',
#  'ร.ต.',
#  'ร.ต.ต.',
#  'ร.ต.ท.',
#  'ร.ต.อ.',
#  'ว่าที่ ร.ต.',
#  'ว่าที่ ร.ท.',
#  'ว่าที่ร้อยตรี',
#  'ส.อ.',
#  'ืนาง',
#  'เด็กชาย',
#  'เด็กหญิง'}

# %%
data_drop['title'].replace({'  นาง':'หญิง',
                    ' นาง':'หญิง',
                    ' นางสาว':'หญิง',
                    ' นาย':'ชาย',
                    'Mrs':'หญิง',
                    'ชาย':'ชาย',
                    'ด.ช.':'ชาย',
                    'ด.ญ.':'หญิง',
                    'ด.ต.':'ไม่ระบุ',
                    'น':'ไม่ระบุ',
                    'น.ส':'หญิง',
                    'น.ส ':'หญิง',
                    'น.ส.':'หญิง',
                    'นส':'หญิง',
                    'นส.':'หญิง',
                    'นส. ':'หญิง',
                    'นาง':'หญิง',
                    'นาง ':'หญิง',
                    'นาง.':'หญิง',
                    'นางl':'หญิง',
                    'นางสาว':'หญิง',
                    'นางสาว ':'หญิง',
                    'นางสาว                   ':'หญิง',
                    'นาน':'ชาย',
                    'นาบ':'ชาย',
                    'นาย':'ชาย',
                    'นาย ':'ชาย',
                    'นาย  ':'ชาย',
                    'นาว':'หญิง',
                    'นาวสาว':'หญิง',
                    'นา่ง':'หญิง',
                    'น่าย':'ชาย',
                    'พจอ.':'ไม่ระบุ',
                    'พระ':'ชาย',
                    'พระครุ':'ไม่ระบุ',
                    'พระปลัด':'ไม่ระบุ',
                    'พลฯ':'ไม่ระบุ',
                    'ร.ต.':'ไม่ระบุ',
                    'ร.ต.ต.':'ไม่ระบุ',
                    'ร.ต.ท.':'ไม่ระบุ',
                    'ร.ต.อ.':'ไม่ระบุ',
                    'รต.':'ไม่ระบุ',
                    'ว่าที่ ร.ต.':'ไม่ระบุ',
                    'ว่าที่ ร.ท.':'ไม่ระบุ',
                    'ว่าที่ร้อยตรี':'ไม่ระบุ',
                    0:'ไม่ระบุ',
                    'data is not completed':'ไม่ระบุ',
                    'okp':'ไม่ระบุ',
                    'ส.อ.':'ไม่ระบุ',
                    'ืนาง':'หญิง',
                    'เด็กชาย':'ชาย',
                    'เด็กหญิง':'หญิง'},inplace=True)

# %%
data_drop
# Out:
#         user                                RowKey        date  ov  \
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30   4
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30   4
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  2022-03-30   3
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  2022-03-29   3
# 195    28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402  2022-03-31   0
# ...      ...                                   ...         ...  ..
# 39416  26462                        ieotqfnqcq.png  2022-03-22   1
# 39417  26462                        cywpeqziic.png  2022-03-21   2
# 39418  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7  2022-03-22   2
# 39419  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC  2022-03-21   0
# 39420  26462                        vdxxgljykj.png  2022-03-21   1
#
#             phone   site      time                             urine  \
# 191    iPhone12,3  06307  14-46-08                   ปกติ (เหลืองใส)
# 192    iPhone14,3  05328  15-27-45                   ปกติ (เหลืองใส)
# 193    iPhone13,4  06302  10-16-46                   ปกติ (เหลืองใส)
# 194     iPhone9,4  05059  12-26-38                   ปกติ (เหลืองใส)
# 195    iPhone13,3  06334  14-57-41                   ปกติ (เหลืองใส)
# ...           ...    ...       ...                               ...
# 39416   Vivo 1920  11069  14-03-12                   ปกติ (เหลืองใส)
# 39417   Vivo 1920  11069  13-59-04                   ปกติ (เหลืองใส)
# 39418  iPhone13,4  11069  13-41-47                   ปกติ (เหลืองใส)
# 39419  iPhone13,4  11069  14-17-46                   ปกติ (เหลืองใส)
# 39420  Vivo V2050  11069  10-54-49  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า
#
#       PartitionKey title  age
# 191          00001  หญิง   47
# 192          00001  หญิง   41
# 193          00001  หญิง   55
# 194          00001   ชาย   66
# 195          00001  หญิง   50
# ...            ...   ...  ...
# 39416        11003  หญิง   33
# 39417        11005   ชาย   28
# 39418        11006  หญิง   72
# 39419        11007  หญิง   48
# 39420        11008   ชาย   36
#
# [37392 rows x 11 columns]

# %%
data_drop2 = data_drop.rename(columns={'title':'sex'})         #เปลี่ยน title เป็น sex

# %%
data_drop2
# Out:
#         user                                RowKey        date  ov  \
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30   4
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30   4
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  2022-03-30   3
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  2022-03-29   3
# 195    28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402  2022-03-31   0
# ...      ...                                   ...         ...  ..
# 39416  26462                        ieotqfnqcq.png  2022-03-22   1
# 39417  26462                        cywpeqziic.png  2022-03-21   2
# 39418  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7  2022-03-22   2
# 39419  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC  2022-03-21   0
# 39420  26462                        vdxxgljykj.png  2022-03-21   1
#
#             phone   site      time                             urine  \
# 191    iPhone12,3  06307  14-46-08                   ปกติ (เหลืองใส)
# 192    iPhone14,3  05328  15-27-45                   ปกติ (เหลืองใส)
# 193    iPhone13,4  06302  10-16-46                   ปกติ (เหลืองใส)
# 194     iPhone9,4  05059  12-26-38                   ปกติ (เหลืองใส)
# 195    iPhone13,3  06334  14-57-41                   ปกติ (เหลืองใส)
# ...           ...    ...       ...                               ...
# 39416   Vivo 1920  11069  14-03-12                   ปกติ (เหลืองใส)
# 39417   Vivo 1920  11069  13-59-04                   ปกติ (เหลืองใส)
# 39418  iPhone13,4  11069  13-41-47                   ปกติ (เหลืองใส)
# 39419  iPhone13,4  11069  14-17-46                   ปกติ (เหลืองใส)
# 39420  Vivo V2050  11069  10-54-49  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า
#
#       PartitionKey   sex  age
# 191          00001  หญิง   47
# 192          00001  หญิง   41
# 193          00001  หญิง   55
# 194          00001   ชาย   66
# 195          00001  หญิง   50
# ...            ...   ...  ...
# 39416        11003  หญิง   33
# 39417        11005   ชาย   28
# 39418        11006  หญิง   72
# 39419        11007  หญิง   48
# 39420        11008   ชาย   36
#
# [37392 rows x 11 columns]

# %%
set(data_drop2['sex'])
# Out:
# {'ชาย', 'หญิง', 'ไม่ระบุ'}

# %% [markdown]
# # Data 2 hospital

# %%
data2 = pd.read_excel(os.path.join(path,'hospital_list.xlsx'))
data2
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 0            สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 1          สาขาพื้นที่(สระบุรี)          12.0          นนทบุรี         1.0
# 2          สาขาพื้นที่(สระบุรี)          13.0         ปทุมธานี         1.0
# 3          สาขาพื้นที่(สระบุรี)          14.0  พระนครศรีอยุธยา         1.0
# 4          สาขาพื้นที่(สระบุรี)          15.0          อ่างทอง         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode     tambon  code4  \
# 0      เมืองสมุทรปราการ         1.0     ปากน้ำ    1.0
# 1          เมืองนนทบุรี         4.0   บางกระสอ    1.0
# 2         เมืองปทุมธานี         1.0    บางปรอก    1.0
# 3       พระนครศรีอยุธยา         3.0  หอรัตนไชย    1.0
# 4          เมืองอ่างทอง         8.0    บ้านอิฐ    1.0
# ...                 ...         ...        ...    ...
# 17098    เมืองอุตรดิตถ์         1.0     ท่าอิฐ    8.0
# 17099           กุยบุรี         1.0    กุยบุรี    8.0
# 17100           วัดเพลง         3.0    วัดเพลง    8.0
# 17101     เมืองศรีสะเกษ        11.0     โพนข่า    8.0
# 17102             บางแพ         2.0    วังเย็น    8.0
#
#                           name5  code9     name10 short_thai short_english
# 0      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         สป           SPK
# 1      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         นบ           NBI
# 2      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         ปท           PTE
# 3      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อย           AYA
# 4      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อท           ATG
# ...                         ...    ...        ...        ...           ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         อต           UTT
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ปข           PKN
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ศก           SSK
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
#
# [17103 rows x 16 columns]

# %%
data_h2 = data2[['hcode','name','zone_name','province','amphur','tambon','name5','short_english']]      # เลือกเฉพาะคอลัมน์ที่ต้องการ
data_h2
# Out:
#        hcode                                               name  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง
# ...      ...                                                ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ
#
#                       zone_name         province            amphur     tambon  \
# 0            สาขาพื้นที่(ระยอง)      สมุทรปราการ  เมืองสมุทรปราการ     ปากน้ำ
# 1          สาขาพื้นที่(สระบุรี)          นนทบุรี      เมืองนนทบุรี   บางกระสอ
# 2          สาขาพื้นที่(สระบุรี)         ปทุมธานี     เมืองปทุมธานี    บางปรอก
# 3          สาขาพื้นที่(สระบุรี)  พระนครศรีอยุธยา   พระนครศรีอยุธยา  หอรัตนไชย
# 4          สาขาพื้นที่(สระบุรี)          อ่างทอง      เมืองอ่างทอง    บ้านอิฐ
# ...                         ...              ...               ...        ...
# 17098     สาขาพื้นที่(พิษณุโลก)        อุตรดิตถ์    เมืองอุตรดิตถ์     ท่าอิฐ
# 17099      สาขาพื้นที่(ราชบุรี)  ประจวบคีรีขันธ์           กุยบุรี    กุยบุรี
# 17100      สาขาพื้นที่(ราชบุรี)          ราชบุรี           วัดเพลง    วัดเพลง
# 17101  สาขาพื้นที่(อุบลราชธานี)         ศรีสะเกษ     เมืองศรีสะเกษ     โพนข่า
# 17102      สาขาพื้นที่(ราชบุรี)          ราชบุรี             บางแพ    วังเย็น
#
#                           name5 short_english
# 0      สำนักงานสาธารณสุขจังหวัด           SPK
# 1      สำนักงานสาธารณสุขจังหวัด           NBI
# 2      สำนักงานสาธารณสุขจังหวัด           PTE
# 3      สำนักงานสาธารณสุขจังหวัด           AYA
# 4      สำนักงานสาธารณสุขจังหวัด           ATG
# ...                         ...           ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.           UTT
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.           PKN
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.           RBR
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.           SSK
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.           RBR
#
# [17103 rows x 8 columns]

# %%
data_h2.isnull().sum()
# Out:
# hcode              0
# name               1
# zone_name          4
# province           0
# amphur             2
# tambon           209
# name5              3
# short_english      6
# dtype: int64

# %%
data_h2['name'] = data_h2['name'].fillna('ไม่ระบุ') 
data_h2['zone_name'] = data_h2['zone_name'].fillna('ไม่ระบุ') 
data_h2['amphur'] = data_h2['amphur'].fillna('ไม่ระบุ') 
data_h2['tambon'] = data_h2['tambon'].fillna('ไม่ระบุ') 
data_h2['name5'] = data_h2['name5'].fillna('ไม่ระบุ') 
data_h2['short_english'] = data_h2['short_english'].fillna('ไม่ระบุ');
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data_h2.isnull().sum()
# Out:
# hcode            0
# name             0
# zone_name        0
# province         0
# amphur           0
# tambon           0
# name5            0
# short_english    0
# dtype: int64

# %%
data_df = data_drop2.merge(data_h2,how='left',left_on='site',right_on='hcode')     # เชื่อมตาราง
data_df
# Out:
#         user                                RowKey        date  ov  \
# 0      12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30   4
# 1      91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30   4
# 2      95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  2022-03-30   3
# 3      13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  2022-03-29   3
# 4      28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402  2022-03-31   0
# ...      ...                                   ...         ...  ..
# 37387  26462                        ieotqfnqcq.png  2022-03-22   1
# 37388  26462                        cywpeqziic.png  2022-03-21   2
# 37389  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7  2022-03-22   2
# 37390  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC  2022-03-21   0
# 37391  26462                        vdxxgljykj.png  2022-03-21   1
#
#             phone   site      time                             urine  \
# 0      iPhone12,3  06307  14-46-08                   ปกติ (เหลืองใส)
# 1      iPhone14,3  05328  15-27-45                   ปกติ (เหลืองใส)
# 2      iPhone13,4  06302  10-16-46                   ปกติ (เหลืองใส)
# 3       iPhone9,4  05059  12-26-38                   ปกติ (เหลืองใส)
# 4      iPhone13,3  06334  14-57-41                   ปกติ (เหลืองใส)
# ...           ...    ...       ...                               ...
# 37387   Vivo 1920  11069  14-03-12                   ปกติ (เหลืองใส)
# 37388   Vivo 1920  11069  13-59-04                   ปกติ (เหลืองใส)
# 37389  iPhone13,4  11069  13-41-47                   ปกติ (เหลืองใส)
# 37390  iPhone13,4  11069  14-17-46                   ปกติ (เหลืองใส)
# 37391  Vivo V2050  11069  10-54-49  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า
#
#       PartitionKey   sex  age  hcode  \
# 0            00001  หญิง   47  06307
# 1            00001  หญิง   41  05328
# 2            00001  หญิง   55  06302
# 3            00001   ชาย   66  05059
# 4            00001  หญิง   50  06334
# ...            ...   ...  ...    ...
# 37387        11003  หญิง   33  11069
# 37388        11005   ชาย   28  11069
# 37389        11006  หญิง   72  11069
# 37390        11007  หญิง   48  11069
# 37391        11008   ชาย   36  11069
#
#                                                     name  \
# 0      โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านเกาะ  ตำบลบ้านดารา
# 1            โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านโคกประสิทธิ์
# 2                     โรงพยาบาลส่งเสริมสุขภาพตำบลสองห้อง
# 3                  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านดอนดู่
# 4                      โรงพยาบาลส่งเสริมสุขภาพตำบลน้ำพี้
# ...                                                  ...
# 37387                                   โรงพยาบาลเสลภูมิ
# 37388                                   โรงพยาบาลเสลภูมิ
# 37389                                   โรงพยาบาลเสลภูมิ
# 37390                                   โรงพยาบาลเสลภูมิ
# 37391                                   โรงพยาบาลเสลภูมิ
#
#                    zone_name   province     amphur     tambon  \
# 0      สาขาพื้นที่(พิษณุโลก)  อุตรดิตถ์      พิชัย   บ้านดารา
# 1       สาขาพื้นที่(ขอนแก่น)  กาฬสินธุ์    ฆ้องชัย   โคกสะอาด
# 2      สาขาพื้นที่(พิษณุโลก)  อุตรดิตถ์     ฟากท่า    สองห้อง
# 3       สาขาพื้นที่(ขอนแก่น)  มหาสารคาม      นาดูน      หัวดง
# 4      สาขาพื้นที่(พิษณุโลก)  อุตรดิตถ์  ทองแสนขัน     น้ำพี้
# ...                      ...        ...        ...        ...
# 37387   สาขาพื้นที่(ขอนแก่น)   ร้อยเอ็ด    เสลภูมิ  ขวัญเมือง
# 37388   สาขาพื้นที่(ขอนแก่น)   ร้อยเอ็ด    เสลภูมิ  ขวัญเมือง
# 37389   สาขาพื้นที่(ขอนแก่น)   ร้อยเอ็ด    เสลภูมิ  ขวัญเมือง
# 37390   สาขาพื้นที่(ขอนแก่น)   ร้อยเอ็ด    เสลภูมิ  ขวัญเมือง
# 37391   สาขาพื้นที่(ขอนแก่น)   ร้อยเอ็ด    เสลภูมิ  ขวัญเมือง
#
#                              name5 short_english
# 0      โรงพยาบาลส่งเสริมสุขภาพตำบล           UTT
# 1      โรงพยาบาลส่งเสริมสุขภาพตำบล           KSN
# 2      โรงพยาบาลส่งเสริมสุขภาพตำบล           UTT
# 3      โรงพยาบาลส่งเสริมสุขภาพตำบล           MKM
# 4      โรงพยาบาลส่งเสริมสุขภาพตำบล           UTT
# ...                            ...           ...
# 37387               โรงพยาบาลชุมชน           RET
# 37388               โรงพยาบาลชุมชน           RET
# 37389               โรงพยาบาลชุมชน           RET
# 37390               โรงพยาบาลชุมชน           RET
# 37391               โรงพยาบาลชุมชน           RET
#
# [37392 rows x 19 columns]

# %%
data_df.isnull().any()  # ตรวจสอบหาค่า missing
# Out:
# user             False
# RowKey           False
# date             False
# ov               False
# phone            False
# site             False
# time             False
# urine            False
# PartitionKey     False
# sex              False
# age              False
# hcode            False
# name             False
# zone_name        False
# province         False
# amphur           False
# tambon           False
# name5            False
# short_english    False
# dtype: bool

# %% [markdown]
# จากการตรวจสอบพบว่าข้อมูลไม่มีค่า missing แล้ว และข้อมูลพร้อมที่จะนำไปทำ dashboard

# %%
data_df.to_csv(os.path.join(path,'data_df.csv'))  # save ไปเก็บในไดร์ฟ

# %% [markdown]
# ##Dashboard

# %% [markdown]
# https://datastudio.google.com/u/0/reporting/777c1306-b151-4425-be8d-75d23c0bc2f2/page/z7BqC
