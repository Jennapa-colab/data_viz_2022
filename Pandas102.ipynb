# %% [markdown]
# <a href="https://colab.research.google.com/github/Jennapa-colab/data_viz_2022/blob/main/Pandas102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd  
#ใช้ในการจัดการข้อมูลที่เป็นตาราง พวกไฟล์ CSV
import os

# %%
from google.colab import drive  
#เชื่อมต่อ google drive กับ colab
drive.mount('/content/drive')
path = '/content/drive/My Drive/dataviz_2021_data'
# Out:
# Mounted at /content/drive

# %%
data_file_path = os.path.join(path,'pm-20-jan-2021.csv') 
data_df = pd.read_csv(data_file_path)

# %%
data_df.head()
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [5 rows x 10 columns]

# %% [markdown]
# ตรวจสอบค่าใน column

# %%
import numpy as np

# %%
set(data_df['province_of_onset'])   # set รวมค่าที่ซ้ำกันให้เป็น 1 ค่า
# Out:
# {nan,
#  'กระบี่',
#  'กรุงเทพมหานคร',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'คลองใหญ่',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชากบก',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครสวรรค์',
#  'นนทบุรี',
#  'นราธิวาส',
#  'น่าน',
#  'บางบุตร',
#  'บุรีรัมย์',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'พม่า',
#  'พระนครศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภูเก็ต',
#  'มหาสารคาม',
#  'มาบตาพุด',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้อยเอ็ด',
#  'ลพบุรี',
#  'ลำปาง',
#  'ลำพูน',
#  'ศรีสะเกษ',
#  'สกลนคร',
#  'สงขลา',
#  'สตูล',
#  'สมุทรปราการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สมุุทรสงคราม',
#  'สระบุรี',
#  'สระแก้ว',
#  'สิงห์บุรี',
#  'สุพรรณบุรี',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุโขทัย',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'หน้าพระธาตุ',
#  'อำนาจเจริญ',
#  'อุดรธานี',
#  'อุตรดิตถ์',
#  'อุทัยธานี',
#  'อุบลราชธานี',
#  'อ่างทอง',
#  'เชียงราย',
#  'เชียงใหม่',
#  'เพชรบุรี',
#  'เพชรบูรณ์',
#  'เลย',
#  'แพร่',
#  'แม่ฮ่องสอน'}

# %%
len('สมุทรสงคราม')
# Out:
# 11

# %% [markdown]
# ##ต่อตาราง
#
#
#
# * ต่อในแนวแกน Y (เพิ่มจำนวนข้อมูล)
# * ต่อในแนวแกน X (เพิ่มรายละเอียดชองข้อมูล)

# %%
BKK = data_df[data_df['province_of_onset']=='กรุงเทพมหานคร']
BKK.head()
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5    6     1/25/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [5 rows x 10 columns]

# %%
KKC = data_df[data_df['province_of_onset']=='ขอนแก่น']
KKC.head()
# Out:
#        No.  ...                                           risk
# 180    181  ...                                        สนามมวย
# 462    463  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1466  1467  ...                  คนไทยเดินทางกลับจากต่างประเทศ
# 1970  1971  ...  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 2637  2638  ...                  สัมผัสผู้เดินทางจากต่างประเทศ
#
# [5 rows x 10 columns]

# %% [markdown]
# ##ต่อตารางให้เป็นข้อมูล 2 จังหวัด

# %%
dataBKKKKC = pd.concat([BKK,KKC])  
#ในวงเล็บคือ list  
dataBKKKKC
# Out:
#          No.  ...                                         risk
# 0          1  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          4  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          5  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 5          6  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# ...      ...  ...                                          ...
# 9334    9335  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 10610  10611  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11517  11518  ...                         อยู่ระหว่างการสอบสวน
# 11697  11698  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11698  11699  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [2803 rows x 10 columns]

# %%
dataBKKKKC = pd.concat([BKK,KKC,BKK])

# %% [markdown]
# ##ถ้าเอาตารางไม่เหมือนกันมา concat กัน

# %%
BKK2 = data_df[data_df['province_of_onset']=='กรุงเทพมหานคร'][['age','nationality','sex']]
BKK2.head()  #คอลัมน์ไม่เท่ากันก็ต่อกันได้ แต่ถ้าอันไหนไม่มีข้อมูลก็จะขึ้นค่าว่างให้
# Out:
#     age nationality   sex
# 0  61.0       China  หญิง
# 1  74.0       China  หญิง
# 3  68.0       China   ชาย
# 4  66.0       China  หญิง
# 5  33.0       China  หญิง

# %%
KKC2 = data_df[data_df['province_of_onset']=='ขอนแก่น'][['age','nationality','sex']]  #คอลัมน์ไม่เท่ากันก็ต่อกันได้ แต่ถ้าอันไหนไม่มีข้อมูลก็จะขึ้นค่าว่างให้
KKC2.head()
# Out:
#        age nationality   sex
# 180   33.0    Thailand   ชาย
# 462   36.0    Thailand  หญิง
# 1466  19.0    Thailand   ชาย
# 1970  70.0    Thailand  หญิง
# 2637  63.0    Thailand  หญิง

# %%
pd.concat([BKK2,KKC2])
# Out:
#         age nationality   sex
# 0      61.0       China  หญิง
# 1      74.0       China  หญิง
# 3      68.0       China   ชาย
# 4      66.0       China  หญิง
# 5      33.0       China  หญิง
# ...     ...         ...   ...
# 9334   20.0    Thailand   ชาย
# 10610  17.0    Thailand   ชาย
# 11517  12.0    Thailand   ชาย
# 11697  17.0    Thailand  หญิง
# 11698  37.0    Thailand  หญิง
#
# [2803 rows x 3 columns]

# %%
KKC3 = data_df[data_df['province_of_onset']=='ขอนแก่น'][['age','nationality','risk']]
KKC3.head() #คอลัมน์ไม่เท่ากันก็ต่อกันได้ แต่ถ้าอันไหนไม่มีข้อมูลก็จะขึ้นค่าว่างให้
# Out:
#        age nationality                                           risk
# 180   33.0    Thailand                                        สนามมวย
# 462   36.0    Thailand    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1466  19.0    Thailand                  คนไทยเดินทางกลับจากต่างประเทศ
# 1970  70.0    Thailand  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 2637  63.0    Thailand                  สัมผัสผู้เดินทางจากต่างประเทศ

# %%
KKC4 = data_df[data_df['province_of_onset']=='ขอนแก่น'][['age','nationality',]]
KKC4.head() #คอลัมน์ไม่เท่ากันก็ต่อกันได้ แต่ถ้าอันไหนไม่มีข้อมูลก็จะขึ้นค่าว่างให้
# Out:
#        age nationality
# 180   33.0    Thailand
# 462   36.0    Thailand
# 1466  19.0    Thailand
# 1970  70.0    Thailand
# 2637  63.0    Thailand

# %%
pd.concat([BKK2,KKC4])
# Out:
#         age nationality   sex
# 0      61.0       China  หญิง
# 1      74.0       China  หญิง
# 3      68.0       China   ชาย
# 4      66.0       China  หญิง
# 5      33.0       China  หญิง
# ...     ...         ...   ...
# 9334   20.0    Thailand   NaN
# 10610  17.0    Thailand   NaN
# 11517  12.0    Thailand   NaN
# 11697  17.0    Thailand   NaN
# 11698  37.0    Thailand   NaN
#
# [2803 rows x 3 columns]

# %% [markdown]
# ##ต่อแกน X

# %%
personal_data = data_df[['No.','sex','age','nationality']]
personal_data.head()
# Out:
#    No.   sex   age nationality
# 0    1  หญิง  61.0       China
# 1    2  หญิง  74.0       China
# 2    3  หญิง  73.0    Thailand
# 3    4   ชาย  68.0       China
# 4    5  หญิง  66.0       China

# %%
covid_data = data_df[['No.','announce_date','province_of_isolation','province_of_onset','risk']].sample(frac=1) # frac คือสลับแถว อาจจะไม่เหมือนกันทุกคน
covid_data.head()
# Out:
#        No.  ...                                         risk
# 9019  9020  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3250  3251  ...                             State Quarantine
# 4091  4092  ...                             State Quarantine
# 4949  4950  ...                            Cluster สมุทรสาคร
# 6628  6629  ...                                Cluster ระยอง
#
# [5 rows x 5 columns]

# %% [markdown]
# ##เอาตารางสองอันมาต่อกัน

# %%
personalcovid_data = personal_data.merge(covid_data)  #ตารางหลักคือ personal_data
personalcovid_data.head()
# Out:
#    No.   sex  ...  province_of_onset                              risk
# 0    1  หญิง  ...      กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2  หญิง  ...      กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3  หญิง  ...             นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4   ชาย  ...      กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5  หญิง  ...      กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [5 rows x 8 columns]

# %% [markdown]
# ##Save Table

# %%
personalcovid_data.to_csv(os.path.join(path,'my_processed_data.csv'))

# %%
personalcovid_data.to_csv('my_processed_data.csv') #มี 2 แบบ

# %% [markdown]
# # Groupby
#
# https://www.kaggle.com/crawford/python-groupby-tutorial#

# %%
data_df.groupby('nationality').count()
# Out:
#                 No.  announce_date  ...  district_of_onset  risk
# nationality                         ...
# Afghanistan       1              1  ...                  1     1
# Albania           3              3  ...                  2     3
# American          1              1  ...                  1     1
# American          1              1  ...                  1     1
# American Samoa    1              1  ...                  1     1
# ...             ...            ...  ...                ...   ...
# deutsch           1              1  ...                  1     1
# thailand          2              2  ...                  2     2
# ต่างด้าว         21             21  ...                 21    21
# ไทยใหญ่           1              1  ...                  1     1
# ไทใหญ่            1              1  ...                  1     1
#
# [100 rows x 9 columns]

# %%
data_df.groupby('nationality').mean()
# Out:
#                          No.        age
# nationality
# Afghanistan      4346.000000  31.000000
# Albania          2377.333333  40.666667
# American         3862.000000  39.000000
# American         3905.000000  46.000000
# American Samoa  11687.000000  21.000000
# ...                      ...        ...
# deutsch          3898.000000  55.000000
# thailand         6823.000000  53.500000
# ต่างด้าว         2944.952381  20.000000
# ไทยใหญ่         10379.000000  30.000000
# ไทใหญ่           5983.000000  33.000000
#
# [100 rows x 2 columns]

# %%
data_df.groupby('nationality')['age'].min()
# Out:
# nationality
# Afghanistan       31.0
# Albania           33.0
# American          39.0
# American          46.0
# American Samoa    21.0
#                   ...
# deutsch           55.0
# thailand          50.0
# ต่างด้าว          13.0
# ไทยใหญ่           30.0
# ไทใหญ่            33.0
# Name: age, Length: 100, dtype: float64

# %%
data_df.groupby('nationality').min(' ')
# Out:
#                   No.   age
# nationality
# Afghanistan      4346  31.0
# Albania          1480  33.0
# American         3862  39.0
# American         3905  46.0
# American Samoa  11687  21.0
# ...               ...   ...
# deutsch          3898  55.0
# thailand         6822  50.0
# ต่างด้าว         2227  13.0
# ไทยใหญ่         10379  30.0
# ไทใหญ่           5983  33.0
#
# [100 rows x 2 columns]

# %% [markdown]
# # Create Pandas table

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %%
import pandas as pd

# %% [markdown]
# ## Dictionary(row oriented)

# %%
data_list = [{'account':'Jones LLC','Jan':150,'Feb':200,'Mar':140},#สร้าง list ของ row สามารถเปลี่ยนค่าได้
         {'account':'Alpha','Jan':200,'Feb':210,'Mar':215},
         {'account':'Blue Inc','Jan':50,'Feb':90,'Mar':95}]
data_list
# Out:
# [{'Feb': 200, 'Jan': 150, 'Mar': 140, 'account': 'Jones LLC'},
#  {'Feb': 210, 'Jan': 200, 'Mar': 215, 'account': 'Alpha'},
#  {'Feb': 90, 'Jan': 50, 'Mar': 95, 'account': 'Blue Inc'}]

# %%
data_list
# Out:
# [{'Feb': 200, 'Jan': 150, 'Mar': 140, 'account': 'Jones LLC'},
#  {'Feb': 210, 'Jan': 200, 'Mar': 215, 'account': 'Alpha'},
#  {'Feb': 90, 'Jan': 50, 'Mar': 95, 'account': 'Blue Inc'}]

# %%
df1 = pd.DataFrame(data_list)
df1
# Out:
#      account  Jan  Feb  Mar
# 0  Jones LLC  150  200  140
# 1      Alpha  200  210  215
# 2   Blue Inc   50   90   95

# %% [markdown]
# ## List(row oriented)

# %%
data = [['Jomes LLC',150,200,140],  # สร้าง list ที่เก็บค่าในแต่ละแถว
        ['Alpha',200,210,215],
        ['Blue',50,90,95]]
headers = ['account','Jan','Feb','Mar'] #กำหนดหัวคอลัมน์ ลำดับใน listt ต้องตรงกัน

df2 = pd.DataFrame.from_records(data,columns=headers)
df2
# Out:
#      account  Jan  Feb  Mar
# 0  Jomes LLC  150  200  140
# 1      Alpha  200  210  215
# 2       Blue   50   90   95

# %%
df2 = pd.DataFrame.from_records(data,columns=headers)
df2
# Out:
#      account  Jan  Feb  Mar
# 0  Jomes LLC  150  200  140
# 1      Alpha  200  210  215
# 2       Blue   50   90   95

# %% [markdown]
# ## Dictionary(column oriented)

# %%
data_dict = {'account':['Jones LLC','Alpha Co','Blue Inc'],
             'Jan':[150,200,50],
             'Feb':[200,210,90],
             'Mar':[140,215,95]
}

# %%
df3 = pd.DataFrame.from_dict(data_dict)
df3
# Out:
#      account  Jan  Feb  Mar
# 0  Jones LLC  150  200  140
# 1   Alpha Co  200  210  215
# 2   Blue Inc   50   90   95

# %% [markdown]
# ## List(column oriented)

# %%
data_item = [['account',['Jones LLC','Alpha Co','Blue Inc']],
             ['Jan',[150,200,50]],
             ['Feb',[200,210,90]],
             ['Mar',[140,215,95]]
            ]

# %%
# pandas version บน colab วันที่ 26 JAn มี Bug
#df4 = pd.DataFrame.from_items(data_item)
#df4

# %% [markdown]
# #Quiz กลุ่มครั้งที่ 3
#
# ออกแบบและสร้างตาราง pandas dataframe ที่สามารถนำมาดึงข้อมูลด้วย pandas ด้วย

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![736ECE9D-0C49-45EC-B2D3-5D51DA0213A2.jpeg](data:image/jpeg;base64,...)

# %%
quiz =[['ภาคตะวันออกเฉียงเหนือ',]
      
      ]

# %%
header = ['จังหวัด','6 ภูมิภาค (ภูมิศาสตร์)','4 ภูมิภาค (การเมือง)','6 ภูมิภาค (อุตุนิยมวิทยา)','5 ภูมิภาค (การท่องเที่ยว)']

# %%
df_province = pd.DataFrame.from_records(province_data,columns=header)
df_province
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-5d48999a8b24> in <module>()
# ----> 1 df_province = pd.DataFrame.from_records(province_data,columns=header)
#       2 df_province
#
# NameError: name 'province_data' is not defined
