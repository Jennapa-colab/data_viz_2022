# %% [markdown]
# <a href="https://colab.research.google.com/github/Jennapa-colab/data_viz_2022/blob/main/cleandata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', None)

# %config InlineBackend.figure_format='retina'

# %%
print(f'Python version:  {sys.version}')
print(f'pandas version:  {pd.__version__}')

pd.Timestamp.now()
# Out:
# Python version:  3.8.10 (default, Nov 14 2022, 12:59:47)
# [GCC 9.4.0]
# pandas version:  1.3.5
# Timestamp('2023-02-16 15:03:15.724063')

# %% [markdown]
# read data

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# %%
path = '/content/drive/My Drive/midterm data 2022'
data_cases = pd.read_excel(os.path.join(path, 'student.xlsx'))

# %%
data_cases
# Out:
#                   Timestamp 1. เพศ 2. ชั้นปีที่ศึกษา    \
# 0   2023-01-28 11:03:30.267    ชาย         ชั้นปีที่ 4
# 1   2023-01-28 13:50:39.118   หญิง         ชั้นปีที่ 4
# 2   2023-01-28 14:33:47.708   หญิง         ชั้นปีที่ 4
# 3   2023-01-29 21:33:31.109   หญิง         ชั้นปีที่ 2
# 4   2023-01-29 21:37:30.271    ชาย         ชั้นปีที่ 2
# 5   2023-01-29 21:41:05.562   หญิง         ชั้นปีที่ 2
# 6   2023-01-29 21:43:24.348   หญิง         ชั้นปีที่ 3
# 7   2023-01-29 21:59:35.336   หญิง         ชั้นปีที่ 2
# 8   2023-01-29 22:06:25.352    ชาย         ชั้นปีที่ 2
# 9   2023-01-31 10:22:20.389    ชาย         ชั้นปีที่ 3
# 10  2023-01-31 10:37:51.163   หญิง         ชั้นปีที่ 4
# 11  2023-01-31 10:39:47.439   หญิง         ชั้นปีที่ 4
# 12  2023-01-31 10:47:06.414   หญิง         ชั้นปีที่ 4
# 13  2023-01-31 10:52:32.368   หญิง         ชั้นปีที่ 2
# 14  2023-01-31 11:11:51.462    ชาย         ชั้นปีที่ 4
# 15  2023-01-31 11:12:08.404   หญิง         ชั้นปีที่ 3
# ...

# %%
data_cases.isnull().any()
# Out:
# Timestamp                                                                                                  False
# 1. เพศ                                                                                                     False
# 2. ชั้นปีที่ศึกษา                                                                                          False
# 3. สาขาวิชาที่ศึกษา                                                                                        False
# 4. อุปกรณ์ที่ใช้ในการเรียน การทำงาน หรือทำการบ้านออนไลน์ (เลือกได้มากกว่า 1 คำตอบ)                         False
# 5. ลักษณะของสถานที่ที่ใช้ในการเรียน การทำงาน หรือทำการบ้านออนไลน์                                          False
# 1. อาการปวดเมื่อยกล้ามเนื้อ คอ บ่าไหล่ และหลัง [ระยะที่ 1]                                                 False
# 1. อาการปวดเมื่อยกล้ามเนื้อ คอ บ่าไหล่ และหลัง [ระยะที่ 2]                                                 False
# ...

# %%
casedrop = pd.read_excel(os.path.join(path, 'student.xlsx'))

# %%
casedrop_clean = casedrop.dropna() 
casedrop_clean
# Out:
#                   Timestamp 1. เพศ 2. ชั้นปีที่ศึกษา    \
# 21  2023-01-31 12:19:31.637    ชาย         ชั้นปีที่ 4
# 24  2023-01-31 12:36:53.424   หญิง         ชั้นปีที่ 4
# 30  2023-01-31 20:34:55.291   หญิง         ชั้นปีที่ 4
# 37  2023-02-02 15:56:32.300    ชาย         ชั้นปีที่ 3
# 48  2023-02-08 08:26:00.155   หญิง         ชั้นปีที่ 4
# 49  2023-02-08 13:11:23.450    ชาย         ชั้นปีที่ 2
# 50  2023-02-08 22:07:40.898    ชาย         ชั้นปีที่ 4
# 57  2023-02-09 01:32:54.915   หญิง         ชั้นปีที่ 2
# 58  2023-02-09 01:58:48.020    ชาย         ชั้นปีที่ 2
# 62  2023-02-10 11:09:40.718   หญิง         ชั้นปีที่ 2
# 66  2023-02-15 12:28:12.005    ชาย         ชั้นปีที่ 2
# 68  2023-02-15 12:29:25.729   หญิง         ชั้นปีที่ 2
# 88  2023-02-15 18:30:09.972    ชาย         ชั้นปีที่ 2
# 92  2023-02-15 20:49:45.656   หญิง         ชั้นปีที่ 3
# 103 2023-02-16 13:27:58.421    ชาย         ชั้นปีที่ 4
#
#              3. สาขาวิชาที่ศึกษา  \
# 21                         สถิติ
# ...

# %%
casedrop_clean.isnull().any()
# Out:
# Timestamp                                                                                                  False
# 1. เพศ                                                                                                     False
# 2. ชั้นปีที่ศึกษา                                                                                          False
# 3. สาขาวิชาที่ศึกษา                                                                                        False
# 4. อุปกรณ์ที่ใช้ในการเรียน การทำงาน หรือทำการบ้านออนไลน์ (เลือกได้มากกว่า 1 คำตอบ)                         False
# 5. ลักษณะของสถานที่ที่ใช้ในการเรียน การทำงาน หรือทำการบ้านออนไลน์                                          False
# 1. อาการปวดเมื่อยกล้ามเนื้อ คอ บ่าไหล่ และหลัง [ระยะที่ 1]                                                 False
# 1. อาการปวดเมื่อยกล้ามเนื้อ คอ บ่าไหล่ และหลัง [ระยะที่ 2]                                                 False
# ...

# %%
casedrop_clean.shape #ขนาดของตาราง dropna
# Out:
# (15, 78)

# %%
removes = data_cases.shape[0] - casedrop_clean.shape[0]
print(f'size before drop = {data_cases.shape[0]}')
print(f'size after drop = {casedrop_clean.shape[0]}')
print(f'% from drop = {(removes/data_cases.shape[0])*100}')
# Out:
# size before drop = 108
# size after drop = 15
# % from drop = 86.11111111111111

# %%
case = data_cases.fillna(value={'Notified date':'ไม่มีข้อมูล','sex':'ไม่มีข้อมูล','Unit':'ปี','nationality':'ไม่มีข้อมูล','province_of_isolation':'ไม่มีข้อมูล','risk':'ไม่มีข้อมูล','province_of_onset':'ไม่มีข้อมูล','district_of_onset':'ไม่มีข้อมูล'}) #แทนด้วยคำว่า ไม่มีข้อมูล ได้เนื่องจากในตารางมีค่าว่าง และในคอลัมป์ไม่มีค่าเป็นตัวเลขจึงใช้ค่า string ในการแทนที่ได้

# %%
case
# Out:
#                   Timestamp 1. เพศ 2. ชั้นปีที่ศึกษา    \
# 0   2023-01-28 11:03:30.267    ชาย         ชั้นปีที่ 4
# 1   2023-01-28 13:50:39.118   หญิง         ชั้นปีที่ 4
# 2   2023-01-28 14:33:47.708   หญิง         ชั้นปีที่ 4
# 3   2023-01-29 21:33:31.109   หญิง         ชั้นปีที่ 2
# 4   2023-01-29 21:37:30.271    ชาย         ชั้นปีที่ 2
# 5   2023-01-29 21:41:05.562   หญิง         ชั้นปีที่ 2
# 6   2023-01-29 21:43:24.348   หญิง         ชั้นปีที่ 3
# 7   2023-01-29 21:59:35.336   หญิง         ชั้นปีที่ 2
# 8   2023-01-29 22:06:25.352    ชาย         ชั้นปีที่ 2
# 9   2023-01-31 10:22:20.389    ชาย         ชั้นปีที่ 3
# 10  2023-01-31 10:37:51.163   หญิง         ชั้นปีที่ 4
# 11  2023-01-31 10:39:47.439   หญิง         ชั้นปีที่ 4
# 12  2023-01-31 10:47:06.414   หญิง         ชั้นปีที่ 4
# 13  2023-01-31 10:52:32.368   หญิง         ชั้นปีที่ 2
# 14  2023-01-31 11:11:51.462    ชาย         ชั้นปีที่ 4
# 15  2023-01-31 11:12:08.404   หญิง         ชั้นปีที่ 3
# ...

# %%
case.isnull().sum()
# Out:
# Timestamp                                                                                                   0
# 1. เพศ                                                                                                      0
# 2. ชั้นปีที่ศึกษา                                                                                           0
# 3. สาขาวิชาที่ศึกษา                                                                                         0
# 4. อุปกรณ์ที่ใช้ในการเรียน การทำงาน หรือทำการบ้านออนไลน์ (เลือกได้มากกว่า 1 คำตอบ)                          0
# 5. ลักษณะของสถานที่ที่ใช้ในการเรียน การทำงาน หรือทำการบ้านออนไลน์                                           0
# 1. อาการปวดเมื่อยกล้ามเนื้อ คอ บ่าไหล่ และหลัง [ระยะที่ 1]                                                  0
# 1. อาการปวดเมื่อยกล้ามเนื้อ คอ บ่าไหล่ และหลัง [ระยะที่ 2]                                                  0
# ...

# %%
data_04 = case3[['announce_date','age','risk','province_of_onset','district_of_onset']]
data_04
